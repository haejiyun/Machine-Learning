# %% [markdown]
# <img src = "poule.png" style = "height:50">

# %% [markdown]
# <center><h1><span style = "color:indianred">Étude de marché<br><center><font size="4"> - clustering & visualisation - </font></center></br><br><center><font size="4"> version finale</font></center></br></span></h1></center>

# %% [markdown]
# **D'après un premier clustering effectué, le poids de la variable 'population' est bien important pour avoir une classification apportant de l'information utile à notre sujet. De ce fait, un deuxième clustering est effectué sans la variable population**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# %%
data = pd.read_csv("data.csv", index_col = 0).reset_index(drop=True)
data_copy = data.copy()
data = data.drop('Population', axis = 1)

# %% [markdown]
# <h2><span style="color:indianred"> 4. Normalisation des données </span></h2>

# %%
# Aperçu de données

data.head()
# Out:
#              Zone  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0     Afghanistan                                             5.0
# 1  Afrique du Sud                                           143.0
# 2         Albanie                                            85.0
# 3         Algérie                                            22.0
# 4       Allemagne                                            71.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                               1.53
# 1                                              35.69
# 2                                              16.36
# 3                                               6.38
# 4                                              19.47
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                               0.33
# 1                                               9.25
# 2                                               6.45
# 3                                               1.50
# 4                                               4.16
#
#    Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                               0.54
# 1                                              14.11
# 2                                               6.26
# 3                                               1.97
# 4                                               7.96
#
#    Disponibilité intérieure  Exportations - Quantité  Importations - Quantité  \
# 0                      57.0               132.185185                     29.0
# 1                    2118.0                63.000000                    514.0
# 2                      47.0                 0.000000                     38.0
# 3                     277.0                 0.000000                      2.0
# 4                    1739.0               646.000000                    842.0
#
#    Production
# 0        28.0
# 1      1667.0
# 2        13.0
# 3       275.0
# 4      1514.0

# %%
# Info

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 9 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Zone                                                           169 non-null    object
#  1   Disponibilité alimentaire (Kcal/personne/jour)                 169 non-null    float64
#  2   Disponibilité alimentaire en quantité (kg/personne/an)         169 non-null    float64
#  3   Disponibilité de matière grasse en quantité (g/personne/jour)  169 non-null    float64
#  4   Disponibilité de protéines en quantité (g/personne/jour)       169 non-null    float64
#  5   Disponibilité intérieure                                       169 non-null    float64
#  6   Exportations - Quantité                                        169 non-null    float64
#  7   Importations - Quantité                                        169 non-null    float64
#  8   Production                                                     169 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 12.0+ KB

# %%
# Standardisation des valeurs numériques

scaler = StandardScaler()
X_norm = scaler.fit_transform(data.drop('Zone', axis = 1))

# %%
# Combinaison avec valeurs qualitatives

data_norm = pd.merge(data['Zone'], pd.DataFrame(X_norm, columns = data.iloc[:,1:].columns),
                     left_index=True, right_index=True)
data_norm.head()
# Out:
#              Zone  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0     Afghanistan                                       -1.168443
# 1  Afrique du Sud                                        1.116325
# 2         Albanie                                        0.156060
# 3         Algérie                                       -0.886986
# 4       Allemagne                                       -0.075728
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                          -1.199115
# 1                                           0.961707
# 2                                          -0.261030
# 3                                          -0.892324
# 4                                          -0.064304
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                          -1.107754
# 1                                           1.024391
# 2                                           0.355108
# 3                                          -0.828089
# 4                                          -0.192270
#
#    Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                          -1.196185
# 1                                           1.233962
# 2                                          -0.171834
# 3                                          -0.940097
# 4                                           0.132606
#
#    Disponibilité intérieure  Exportations - Quantité  Importations - Quantité  \
# 0                 -0.290056                 0.000000                -0.327248
# 1                  0.652476                -0.151225                 2.272622
# 2                 -0.294629                -0.288930                -0.279003
# 3                 -0.189446                -0.288930                -0.471983
# 4                  0.479153                 1.123095                 4.030885
#
#    Production
# 0   -0.282022
# 1    0.377246
# 2   -0.288055
# 3   -0.182669
# 4    0.315704

# %%
# Describe

data_norm.describe()
# Out:
#        Disponibilité alimentaire (Kcal/personne/jour)  \
# count                                    1.690000e+02
# mean                                     3.875927e-17
# std                                      1.002972e+00
# min                                     -1.251224e+00
# 25%                                     -8.869860e-01
# 50%                                     -1.750656e-01
# 75%                                      5.202985e-01
# max                                      2.771954e+00
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# count                                       1.690000e+02
# mean                                       -6.043818e-17
# std                                         1.002972e+00
# min                                        -1.287673e+00
# 25%                                        -8.493099e-01
# 50%                                        -1.402111e-01
# 75%                                         6.207577e-01
# max                                         3.278139e+00
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# count                                       1.690000e+02
# mean                                       -2.562053e-17
# std                                         1.002972e+00
# min                                        -1.179463e+00
# 25%                                        -8.280894e-01
# 50%                                        -2.878823e-01
# 75%                                         4.244262e-01
# max                                         3.082436e+00
#
#        Disponibilité de protéines en quantité (g/personne/jour)  \
# count                                       1.690000e+02
# mean                                        4.861332e-17
# std                                         1.002972e+00
# min                                        -1.285726e+00
# 25%                                        -8.881635e-01
# 50%                                        -1.019921e-01
# 75%                                         5.767298e-01
# max                                         3.698134e+00
#
#        Disponibilité intérieure  Exportations - Quantité  \
# count              1.690000e+02             1.690000e+02
# mean              -2.529206e-17             2.627747e-18
# std                1.002972e+00             1.002972e+00
# min               -3.152082e-01            -2.889301e-01
# 25%               -3.024033e-01            -2.889301e-01
# 50%               -2.694764e-01            -2.714437e-01
# 75%               -1.460007e-01             0.000000e+00
# max                8.037241e+00             8.941694e+00
#
#        Importations - Quantité    Production
# count             1.690000e+02  1.690000e+02
# mean              6.405133e-17  2.266432e-17
# std               1.002972e+00  1.002972e+00
# min              -4.827038e-01 -2.932842e-01
# 25%              -4.666222e-01 -2.876529e-01
# 50%              -3.969349e-01 -2.643231e-01
# 75%              -4.313821e-02 -1.070482e-01
# max               5.247731e+00  8.521350e+00

# %% [markdown]
# <h2><span style="color:indianred"> 5. ACP </span></h2>

# %% [markdown]
# ### ACP 2 components

# %%
# PCA

model_2 = PCA(n_components = 2)
pca_2 = model_2.fit_transform(data_norm.drop('Zone', axis = 1))

# %%
# Visualisation

fig = plt.figure(figsize = (10,8))

ax = fig.add_subplot(111)
ax.scatter(pca_2[:, 0], pca_2[:, 1], color = 'mediumpurple', s = 75)
plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)

ax.set_xlabel('pca 1', size = 15)
ax.set_ylabel('pca 2', size = 15)

ax.set_title("\nDonnées projetées sur les 2 axes de PCA\n", fontsize = 18, color ='dimgray')
plt.tick_params(labelsize=15)
plt.show();

print("La part de variance expliquée est", round(model_2.explained_variance_ratio_.sum(),2))
# Out:
# La part de variance expliquée est 0.82

# %% [markdown]
# ### ACP 3 components

# %%
# PCA

model_3 = PCA(n_components = 3)
pca_3 = model_3.fit_transform(data_norm.drop('Zone', axis = 1))

# %%
# Visualisation

fig = plt.figure(figsize = (15,10))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_3[:, 0], pca_3[:, 1], pca_3[:, 2], color = 'mediumpurple', s = 75)
plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)

ax.set_xlabel('pca 1', size = 15)
ax.set_ylabel('pca 2', size = 15)
ax.set_zlabel('pca 3', size = 15)

ax.set_title("\nDonnées projetées sur les 3 axes de PCA", fontsize = 18, color ='dimgray')
plt.show();

print("La part de variance expliquée est", round(model_3.explained_variance_ratio_.sum(),2))
# Out:
# La part de variance expliquée est 0.96

# %% [markdown]
# <h2><span style="color:indianred"> 6. Clustering </span></h2>

# %% [markdown]
# ### Dendrogramme

# %%
# Création de données pour le clustering

data_pca = pd.DataFrame(pca_3, index = data.Zone )
data_pca = data_pca.rename(columns={0:"pca 1", 1:"pca 2", 2:"pca 3"})
data_pca.head()
# Out:
#                    pca 1     pca 2     pca 3
# Zone
# Afghanistan     0.281349  0.710437  0.154624
# Afrique du Sud -0.443846 -0.018364  0.100894
# Albanie         0.410416 -0.471617  0.165064
# Algérie        -0.482400 -0.013011 -0.108236
# Allemagne      -0.323656  0.176373  0.186886

# %%
# Dendrogramme

z = linkage(data_pca, method = 'ward', metric = 'euclidean')

plt.figure(figsize=(20,10))
plt.box(False)
plt.tick_params(bottom=False, left=False)
plt.yticks([])
plt.title("\nDendrogramme Classification Ascendant Hiérarchique\n", fontsize = 18, color ='dimgray')
dendrogram(z, labels = data_pca.index, leaf_rotation = 90);

# %% [markdown]
# ### Classification ascendante hiérarchique

# %%
# CAH à deux clusters

cah = AgglomerativeClustering(n_clusters = 4)
cah.fit(data_pca)

cluster_cah = cah.labels_

# %%
# Visualisation

fig = plt.figure(figsize = (15,10))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_3[:, 0], pca_3[:, 1], pca_3[:, 2], c = cluster_cah, cmap = 'Set2', s = 75)
plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)

ax.set_xlabel('pca 1', size = 15)
ax.set_ylabel('pca 2', size = 15)

ax.set_title("\nQuatre clusters de CAH", fontsize = 18);

# %% [markdown]
# ### K-means

# %%
# K-means

kmeans = KMeans(n_clusters = 4)
kmeans.fit(data_pca)

cluster_km = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
# Visualisation

fig = plt.figure(figsize = (15,10))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_3[:, 0], pca_3[:, 1], pca_3[:, 2], c = cluster_km, cmap = 'Set2', s = 75)
ax.scatter(centroids[:, 0],centroids[:, 1], centroids[:, 2], marker = "D", color = "darkred", s=100)

plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)


ax.set_xlabel('pca 1', size = 15)
ax.set_ylabel('pca 2', size = 15)

ax.set_title("\nQuatre clusters de K-means", fontsize = 18);

# %%
# Optimisation de nombre de cluster par méthode de coude

n_clusters = [2, 3, 4, 5, 6]  
distorsions = []

for i in n_clusters:
    cluster = KMeans(n_clusters = i)
    cluster.fit(data_pca)
    distorsions.append(sum(np.min(cdist(data_pca, cluster.cluster_centers_, 'euclidean'), axis=1)) / np.size(data_pca, axis = 0))

    
fig = plt.figure(figsize = (12,8))

ax = fig.add_subplot(111)

plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)

plt.plot(n_clusters, distorsions, 'x-', color = 'slateblue')

plt.xlabel('Nombre de Clusters', fontsize = 15)
plt.ylabel('Distorsion', fontsize = 15)
plt.title("\nMéthode du coude\n", fontsize = 18, color ='dimgray')
plt.tick_params(labelsize=15)
plt.show()

# %%
# K-means à 3 clusters

kmeans_3 = KMeans(n_clusters = 3)
kmeans_3.fit(data_pca)

cluster_km_3 = kmeans_3.labels_
centroids_3 = kmeans_3.cluster_centers_

# %%
# Visualisation

fig = plt.figure(figsize = (15,10))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_3[:, 0], pca_3[:, 1], pca_3[:, 2], c = cluster_km_3, cmap = 'Set2', s = 75)
ax.scatter(centroids_3[:, 0], centroids_3[:, 1], centroids_3[:, 2], marker = "D", color = "darkred", s=100)

plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)


ax.set_xlabel('pca 1', size = 15)
ax.set_ylabel('pca 2', size = 15)

ax.set_title("\nTrois clusters de K-means", fontsize = 18);

# %%
# Données avec clustering

pd.set_option('display.max_row',170)
data_pca['cluster_cah'] = cluster_cah
data_pca['cluster_km'] = cluster_km
data_pca
# Out:
#                                                        pca 1     pca 2  \
# Zone
# Afghanistan                                         0.281349  0.710437
# Afrique du Sud                                     -0.443846 -0.018364
# Albanie                                             0.410416 -0.471617
# Algérie                                            -0.482400 -0.013011
# Allemagne                                          -0.323656  0.176373
# Angola                                             -0.103573 -0.101668
# Antigua-et-Barbuda                                  0.774627 -0.499615
# Arabie saoudite                                    -0.302564 -0.087273
# Argentine                                          -0.456131  0.045258
# Arménie                                             0.274408 -0.420919
# Australie                                          -0.442818 -0.022689
# Autriche                                           -0.135806  0.067978
# Azerbaïdjan                                        -0.320710 -0.157187
# Bahamas                                             0.811365  0.040420
# Bangladesh                                         -0.337560  0.290343
# Barbade                                             0.701354 -0.501062
# Belgique                                            0.156818  0.608330
# Belize                                              0.590257 -0.496371
# Bolivie (État plurinational de)                    -0.376236 -0.098684
# Bosnie-Herzégovine                                 -0.031359 -0.251385
# Botswana                                            0.277103 -0.453299
# Brésil                                             -0.406532  0.222818
# Bulgarie                                           -0.067927 -0.080718
# Burkina Faso                                        0.250063  0.735601
# Bélarus                                            -0.277282  0.158767
# Bénin                                              -0.057329 -0.164809
# Cabo Verde                                          0.757818  0.524595
# Cambodge                                            0.367554  0.751037
# Cameroun                                           -0.458568 -0.037041
# Canada                                             -0.434838  0.030776
# Chili                                              -0.365364  0.010044
# Chine - RAS de Hong-Kong                            0.447338  0.337300
# Chine - RAS de Macao                                0.708611 -0.512336
# Chine, Taiwan Province de                          -0.415465 -0.068174
# Chine, continentale                                -0.505648  0.038063
# Chypre                                              0.421749 -0.480282
# Colombie                                           -0.483390 -0.012445
# Congo                                               0.169227 -0.303325
# Costa Rica                                         -0.180818 -0.236915
# Croatie                                            -0.090567 -0.084256
# Cuba                                                0.082539  0.062319
# Côte d'Ivoire                                      -0.450428 -0.047231
# Danemark                                            0.039125  0.128287
# Djibouti                                           -0.257324  0.258490
# Dominique                                           0.776283 -0.499030
# El Salvador                                        -0.260673 -0.188197
# Espagne                                            -0.443228  0.062473
# Estonie                                             0.515383 -0.404472
# Eswatini                                            0.468501 -0.491182
# Fidji                                               0.512368 -0.493996
# Finlande                                           -0.225672 -0.150175
# France                                             -0.386058  0.150385
# Fédération de Russie                               -0.497182  0.022633
# Gabon                                               0.368623 -0.422807
# Gambie                                              0.608168  0.803734
# Ghana                                              -0.214020 -0.085488
# Grenade                                             0.867985  0.032343
# Grèce                                              -0.343265 -0.010001
# Guatemala                                          -0.341508 -0.103394
# Guinée                                              0.401861  0.680945
# Guinée-Bissau                                       0.598216  0.847332
# Guyana                                              0.575325 -0.496373
# Géorgie                                             0.141269 -0.306819
# Haïti                                               0.315718  0.436710
# Honduras                                           -0.297942 -0.170837
# Hongrie                                            -0.224674  0.216547
# Inde                                               -0.513213  0.021238
# Indonésie                                          -0.510768  0.017906
# Iran (République islamique d')                     -0.492119  0.013748
# Iraq                                               -0.135496 -0.093357
# Irlande                                             0.096623  0.047646
# Islande                                             0.685171 -0.501377
# Israël                                             -0.346458 -0.131567
# Italie                                             -0.454439  0.082819
# Jamaïque                                            0.068890 -0.377079
# Japon                                              -0.449252 -0.013671
# Jordanie                                           -0.293123 -0.148145
# Kazakhstan                                         -0.281020 -0.112348
# Kenya                                              -0.491984 -0.002515
# Kirghizistan                                       -0.048013 -0.205122
# Kiribati                                            0.787033  0.535235
# Koweït                                              0.139722 -0.348389
# Lesotho                                             0.420423 -0.461303
# Lettonie                                            0.338996 -0.265673
# Liban                                              -0.229894 -0.184423
# Libéria                                             0.108812 -0.309803
# Lituanie                                            0.087854  0.001010
# Luxembourg                                          0.712103 -0.503658
# Macédoine du Nord                                   0.454534 -0.452574
# Madagascar                                          0.048631  0.588834
# Malaisie                                           -0.474450  0.001229
# Malawi                                             -0.084016  0.493682
# Maldives                                           -0.233427  0.223026
# Mali                                                0.226449  0.713939
# Malte                                               0.698707 -0.510827
# Maroc                                              -0.477314 -0.016397
# Maurice                                             0.379134 -0.469025
# Mauritanie                                          0.536790  0.772857
# Mexique                                            -0.467910 -0.017265
# Mongolie                                            0.601132  0.824536
# Monténégro                                          0.655275 -0.512429
# Mozambique                                         -0.040852  0.499565
# Myanmar                                            -0.487140 -0.007768
# Namibie                                             0.371862 -0.257833
# Nicaragua                                          -0.207965 -0.231147
# Niger                                              -0.439627 -0.056913
# Nigéria                                            -0.511054  0.018328
# Norvège                                            -0.207975 -0.232105
# Nouvelle-Calédonie                                  0.845492  0.185560
# Nouvelle-Zélande                                   -0.159276 -0.173497
# Népal                                               0.162537  0.697335
# Oman                                                0.203530 -0.213653
# Ouganda                                            -0.483645 -0.011673
# Pakistan                                           -0.508357  0.017896
# Panama                                             -0.231030 -0.217947
# Paraguay                                           -0.258762 -0.132138
# Pays-Bas                                            0.106285  0.615034
# Philippines                                        -0.481817 -0.010729
# Pologne                                            -0.296825  0.325293
# Polynésie française                                 0.742075 -0.508809
# Portugal                                           -0.329443 -0.049441
# Pérou                                              -0.496047  0.000889
# Roumanie                                           -0.364146  0.027735
# Royaume-Uni de Grande-Bretagne et d'Irlande du ... -0.399403  0.061859
# Rwanda                                             -0.399611 -0.090980
# République centrafricaine                           0.556323  0.832559
# République de Corée                                -0.473908 -0.015362
# République de Moldova                              -0.067429 -0.317573
# République dominicaine                             -0.347803 -0.125731
# République populaire démocratique de Corée         -0.437884 -0.056516
# République-Unie de Tanzanie                        -0.082499  0.537391
# Saint-Kitts-et-Nevis                                0.779193 -0.498144
# Saint-Vincent-et-les Grenadines                     0.871083 -0.074287
# Sainte-Lucie                                        0.863724 -0.066011
# Samoa                                               0.756046 -0.506447
# Sao Tomé-et-Principe                                0.708593  0.708032
# Serbie                                             -0.305882 -0.112380
# Sierra Leone                                       -0.228415 -0.190047
# Slovaquie                                          -0.024288 -0.020899
# Slovénie                                            0.165435 -0.182099
# Sri Lanka                                          -0.456066 -0.031041
# Suisse                                             -0.227360 -0.187743
# Suriname                                            0.636440 -0.479820
# Suède                                              -0.273469 -0.082162
# Sénégal                                            -0.425700 -0.067832
# Tadjikistan                                         0.499579  0.683773
# Tchad                                              -0.366944 -0.122169
# Tchéquie                                           -0.231652 -0.109101
# Thaïlande                                          -0.296007  0.351839
# Timor-Leste                                         0.631992  0.802653
# Togo                                               -0.242691 -0.209206
# Trinité-et-Tobago                                   0.400204 -0.481217
# Tunisie                                            -0.389130 -0.082121
# Turkménistan                                        0.462020  0.758887
# Turquie                                            -0.441278  0.143373
# Ukraine                                            -0.415914  0.130426
# Uruguay                                            -0.029616 -0.281745
# Vanuatu                                             0.726845  0.664501
# Venezuela (République bolivarienne du)             -0.464409 -0.032780
# Viet Nam                                           -0.460949 -0.024415
# Yémen                                              -0.398295 -0.075062
# Zambie                                             -0.400205 -0.077003
# Zimbabwe                                            0.108307  0.602543
# Égypte                                             -0.489450 -0.006444
# Émirats arabes unis                                 0.091993 -0.072621
# Équateur                                           -0.410718 -0.081329
# États-Unis d'Amérique                              -0.463690  0.129297
# Éthiopie                                            0.478976  0.867171
# Îles Salomon                                        0.693652 -0.505644
#
#                                                        pca 3  cluster_cah  \
# Zone
# Afghanistan                                         0.154624            2
# Afrique du Sud                                      0.100894            0
# Albanie                                             0.165064            1
# Algérie                                            -0.108236            0
# Allemagne                                           0.186886            0
# Angola                                              0.678501            1
# Antigua-et-Barbuda                                 -0.224592            3
# Arabie saoudite                                     0.410046            0
# Argentine                                          -0.142706            0
# Arménie                                             0.290769            1
# Australie                                          -0.143520            0
# Autriche                                            0.198593            0
# Azerbaïdjan                                         0.023402            0
# Bahamas                                            -0.109698            3
# Bangladesh                                         -0.102382            0
# Barbade                                            -0.252133            3
# Belgique                                            0.054476            2
# Belize                                             -0.270430            3
# Bolivie (État plurinational de)                    -0.212071            0
# Bosnie-Herzégovine                                 -0.166764            0
# Botswana                                           -0.047710            3
# Brésil                                             -0.204053            0
# Bulgarie                                            0.267782            0
# Burkina Faso                                       -0.083376            2
# Bélarus                                            -0.258760            0
# Bénin                                               0.628853            1
# Cabo Verde                                         -0.054717            2
# Cambodge                                            0.002512            2
# Cameroun                                           -0.119275            0
# Canada                                             -0.047180            0
# Chili                                              -0.034884            0
# Chine - RAS de Hong-Kong                            0.584991            1
# Chine - RAS de Macao                               -0.097681            3
# Chine, Taiwan Province de                           0.044815            0
# Chine, continentale                                -0.090040            0
# Chypre                                             -0.108182            3
# Colombie                                           -0.071552            0
# Congo                                               0.561259            1
# Costa Rica                                         -0.130932            0
# Croatie                                            -0.060042            0
# Cuba                                                0.646871            1
# Côte d'Ivoire                                      -0.027075            0
# Danemark                                            0.134939            0
# Djibouti                                           -0.504475            0
# Dominique                                          -0.228379            3
# El Salvador                                        -0.127780            0
# Espagne                                            -0.043759            0
# Estonie                                            -0.058364            3
# Eswatini                                           -0.186173            3
# Fidji                                              -0.232786            3
# Finlande                                           -0.156557            0
# France                                              0.017172            0
# Fédération de Russie                               -0.070778            0
# Gabon                                               0.381037            1
# Gambie                                              0.042478            2
# Ghana                                               0.575400            1
# Grenade                                            -0.190716            3
# Grèce                                              -0.039720            0
# Guatemala                                           0.199716            0
# Guinée                                              0.214750            2
# Guinée-Bissau                                      -0.032054            2
# Guyana                                             -0.264445            3
# Géorgie                                             0.368508            1
# Haïti                                               0.452693            1
# Honduras                                           -0.120932            0
# Hongrie                                            -0.222014            0
# Inde                                               -0.092054            0
# Indonésie                                          -0.100154            0
# Iran (République islamique d')                     -0.100813            0
# Iraq                                                0.657769            1
# Irlande                                             0.165800            0
# Islande                                            -0.249811            3
# Israël                                             -0.153958            0
# Italie                                             -0.102742            0
# Jamaïque                                           -0.109285            0
# Japon                                               0.157868            0
# Jordanie                                            0.050039            0
# Kazakhstan                                          0.357112            0
# Kenya                                              -0.110832            0
# Kirghizistan                                        0.557485            1
# Kiribati                                           -0.133805            2
# Koweït                                              0.355660            1
# Lesotho                                             0.258887            1
# Lettonie                                            0.118083            1
# Liban                                              -0.048714            0
# Libéria                                             0.463873            1
# Lituanie                                           -0.107531            0
# Luxembourg                                         -0.081517            3
# Macédoine du Nord                                   0.285676            1
# Madagascar                                         -0.099178            2
# Malaisie                                           -0.112003            0
# Malawi                                             -0.174012            2
# Maldives                                           -0.501217            0
# Mali                                               -0.070067            2
# Malte                                              -0.159794            3
# Maroc                                              -0.120741            0
# Maurice                                            -0.249182            3
# Mauritanie                                          0.115348            2
# Mexique                                             0.108352            0
# Mongolie                                            0.023857            2
# Monténégro                                         -0.116010            3
# Mozambique                                          0.039527            2
# Myanmar                                            -0.110974            0
# Namibie                                             0.265854            1
# Nicaragua                                          -0.179756            0
# Niger                                              -0.015258            0
# Nigéria                                            -0.101702            0
# Norvège                                            -0.178088            0
# Nouvelle-Calédonie                                 -0.147672            3
# Nouvelle-Zélande                                   -0.267589            0
# Népal                                              -0.086415            2
# Oman                                                0.600073            1
# Ouganda                                            -0.109194            0
# Pakistan                                           -0.102992            0
# Panama                                             -0.142944            0
# Paraguay                                           -0.189476            0
# Pays-Bas                                           -0.007364            2
# Philippines                                         0.041978            0
# Pologne                                            -0.272223            0
# Polynésie française                                -0.161061            3
# Portugal                                           -0.056065            0
# Pérou                                              -0.074735            0
# Roumanie                                            0.059543            0
# Royaume-Uni de Grande-Bretagne et d'Irlande du ...  0.148880            0
# Rwanda                                             -0.142330            0
# République centrafricaine                          -0.027730            2
# République de Corée                                -0.020727            0
# République de Moldova                              -0.044781            0
# République dominicaine                             -0.062645            0
# République populaire démocratique de Corée         -0.130305            0
# République-Unie de Tanzanie                        -0.082160            2
# Saint-Kitts-et-Nevis                               -0.234397            3
# Saint-Vincent-et-les Grenadines                    -0.200585            3
# Sainte-Lucie                                       -0.194327            3
# Samoa                                              -0.174657            3
# Sao Tomé-et-Principe                               -0.085637            2
# Serbie                                             -0.073883            0
# Sierra Leone                                        0.265721            0
# Slovaquie                                           0.194964            0
# Slovénie                                           -0.178784            0
# Sri Lanka                                          -0.123153            0
# Suisse                                              0.153009            0
# Suriname                                           -0.096789            3
# Suède                                               0.138904            0
# Sénégal                                            -0.134164            0
# Tadjikistan                                         0.228532            2
# Tchad                                              -0.021743            0
# Tchéquie                                            0.226597            0
# Thaïlande                                          -0.266850            0
# Timor-Leste                                         0.005692            2
# Togo                                                0.076882            0
# Trinité-et-Tobago                                  -0.153569            3
# Tunisie                                            -0.170900            0
# Turkménistan                                       -0.012212            2
# Turquie                                            -0.185786            0
# Ukraine                                            -0.108915            0
# Uruguay                                            -0.179941            0
# Vanuatu                                            -0.082821            2
# Venezuela (République bolivarienne du)             -0.085283            0
# Viet Nam                                            0.116587            0
# Yémen                                               0.179613            0
# Zambie                                              0.042939            0
# Zimbabwe                                           -0.057822            2
# Égypte                                             -0.024555            0
# Émirats arabes unis                                 0.649642            1
# Équateur                                           -0.138133            0
# États-Unis d'Amérique                              -0.154422            0
# Éthiopie                                           -0.047370            2
# Îles Salomon                                        0.043447            3
#
#                                                     cluster_km
# Zone
# Afghanistan                                                  2
# Afrique du Sud                                               1
# Albanie                                                      0
# Algérie                                                      1
# Allemagne                                                    1
# Angola                                                       3
# Antigua-et-Barbuda                                           0
# Arabie saoudite                                              3
# Argentine                                                    1
# Arménie                                                      3
# Australie                                                    1
# Autriche                                                     3
# Azerbaïdjan                                                  1
# Bahamas                                                      0
# Bangladesh                                                   1
# Barbade                                                      0
# Belgique                                                     2
# Belize                                                       0
# Bolivie (État plurinational de)                              1
# Bosnie-Herzégovine                                           1
# Botswana                                                     0
# Brésil                                                       1
# Bulgarie                                                     3
# Burkina Faso                                                 2
# Bélarus                                                      1
# Bénin                                                        3
# Cabo Verde                                                   2
# Cambodge                                                     2
# Cameroun                                                     1
# Canada                                                       1
# Chili                                                        1
# Chine - RAS de Hong-Kong                                     2
# Chine - RAS de Macao                                         0
# Chine, Taiwan Province de                                    1
# Chine, continentale                                          1
# Chypre                                                       0
# Colombie                                                     1
# Congo                                                        3
# Costa Rica                                                   1
# Croatie                                                      1
# Cuba                                                         3
# Côte d'Ivoire                                                1
# Danemark                                                     3
# Djibouti                                                     1
# Dominique                                                    0
# El Salvador                                                  1
# Espagne                                                      1
# Estonie                                                      0
# Eswatini                                                     0
# Fidji                                                        0
# Finlande                                                     1
# France                                                       1
# Fédération de Russie                                         1
# Gabon                                                        3
# Gambie                                                       2
# Ghana                                                        3
# Grenade                                                      0
# Grèce                                                        1
# Guatemala                                                    1
# Guinée                                                       2
# Guinée-Bissau                                                2
# Guyana                                                       0
# Géorgie                                                      3
# Haïti                                                        2
# Honduras                                                     1
# Hongrie                                                      1
# Inde                                                         1
# Indonésie                                                    1
# Iran (République islamique d')                               1
# Iraq                                                         3
# Irlande                                                      3
# Islande                                                      0
# Israël                                                       1
# Italie                                                       1
# Jamaïque                                                     0
# Japon                                                        1
# Jordanie                                                     1
# Kazakhstan                                                   3
# Kenya                                                        1
# Kirghizistan                                                 3
# Kiribati                                                     2
# Koweït                                                       3
# Lesotho                                                      0
# Lettonie                                                     0
# Liban                                                        1
# Libéria                                                      3
# Lituanie                                                     1
# Luxembourg                                                   0
# Macédoine du Nord                                            0
# Madagascar                                                   2
# Malaisie                                                     1
# Malawi                                                       2
# Maldives                                                     1
# Mali                                                         2
# Malte                                                        0
# Maroc                                                        1
# Maurice                                                      0
# Mauritanie                                                   2
# Mexique                                                      1
# Mongolie                                                     2
# Monténégro                                                   0
# Mozambique                                                   2
# Myanmar                                                      1
# Namibie                                                      3
# Nicaragua                                                    1
# Niger                                                        1
# Nigéria                                                      1
# Norvège                                                      1
# Nouvelle-Calédonie                                           0
# Nouvelle-Zélande                                             1
# Népal                                                        2
# Oman                                                         3
# Ouganda                                                      1
# Pakistan                                                     1
# Panama                                                       1
# Paraguay                                                     1
# Pays-Bas                                                     2
# Philippines                                                  1
# Pologne                                                      1
# Polynésie française                                          0
# Portugal                                                     1
# Pérou                                                        1
# Roumanie                                                     1
# Royaume-Uni de Grande-Bretagne et d'Irlande du ...           1
# Rwanda                                                       1
# République centrafricaine                                    2
# République de Corée                                          1
# République de Moldova                                        1
# République dominicaine                                       1
# République populaire démocratique de Corée                   1
# République-Unie de Tanzanie                                  2
# Saint-Kitts-et-Nevis                                         0
# Saint-Vincent-et-les Grenadines                              0
# Sainte-Lucie                                                 0
# Samoa                                                        0
# Sao Tomé-et-Principe                                         2
# Serbie                                                       1
# Sierra Leone                                                 3
# Slovaquie                                                    3
# Slovénie                                                     0
# Sri Lanka                                                    1
# Suisse                                                       1
# Suriname                                                     0
# Suède                                                        1
# Sénégal                                                      1
# Tadjikistan                                                  2
# Tchad                                                        1
# Tchéquie                                                     3
# Thaïlande                                                    1
# Timor-Leste                                                  2
# Togo                                                         1
# Trinité-et-Tobago                                            0
# Tunisie                                                      1
# Turkménistan                                                 2
# Turquie                                                      1
# Ukraine                                                      1
# Uruguay                                                      1
# Vanuatu                                                      2
# Venezuela (République bolivarienne du)                       1
# Viet Nam                                                     1
# Yémen                                                        1
# Zambie                                                       1
# Zimbabwe                                                     2
# Égypte                                                       1
# Émirats arabes unis                                          3
# Équateur                                                     1
# États-Unis d'Amérique                                        1
# Éthiopie                                                     2
# Îles Salomon                                                 0

# %% [markdown]
# ### Visualisation sur la carte

# %%
# Nombre de pays dans chaque cluster 

data_pca.cluster_km.value_counts()
# Out:
# 1    84
# 0    33
# 2    28
# 3    24
# Name: cluster_km, dtype: int64

# %%
# Liste des pays dans clsuter 0

data_pca[data_pca.cluster_km == 0].index
# Out:
# Index(['Albanie', 'Antigua-et-Barbuda', 'Bahamas', 'Barbade', 'Belize',
#        'Botswana', 'Chine - RAS de Macao', 'Chypre', 'Dominique', 'Estonie',
#        'Eswatini', 'Fidji', 'Grenade', 'Guyana', 'Islande', 'Jamaïque',
#        'Lesotho', 'Lettonie', 'Luxembourg', 'Macédoine du Nord', 'Malte',
#        'Maurice', 'Monténégro', 'Nouvelle-Calédonie', 'Polynésie française',
#        'Saint-Kitts-et-Nevis', 'Saint-Vincent-et-les Grenadines',
#        'Sainte-Lucie', 'Samoa', 'Slovénie', 'Suriname', 'Trinité-et-Tobago',
#        'Îles Salomon'],
#       dtype='object', name='Zone')

# %%
# Liste des pays dans clsuter 1

data_pca[data_pca.cluster_km == 1].index
# Out:
# Index(['Afrique du Sud', 'Algérie', 'Allemagne', 'Argentine', 'Australie',
#        'Azerbaïdjan', 'Bangladesh', 'Bolivie (État plurinational de)',
#        'Bosnie-Herzégovine', 'Brésil', 'Bélarus', 'Cameroun', 'Canada',
#        'Chili', 'Chine, Taiwan Province de', 'Chine, continentale', 'Colombie',
#        'Costa Rica', 'Croatie', 'Côte d'Ivoire', 'Djibouti', 'El Salvador',
#        'Espagne', 'Finlande', 'France', 'Fédération de Russie', 'Grèce',
#        'Guatemala', 'Honduras', 'Hongrie', 'Inde', 'Indonésie',
#        'Iran (République islamique d')', 'Israël', 'Italie', 'Japon',
#        'Jordanie', 'Kenya', 'Liban', 'Lituanie', 'Malaisie', 'Maldives',
#        'Maroc', 'Mexique', 'Myanmar', 'Nicaragua', 'Niger', 'Nigéria',
#        'Norvège', 'Nouvelle-Zélande', 'Ouganda', 'Pakistan', 'Panama',
#        'Paraguay', 'Philippines', 'Pologne', 'Portugal', 'Pérou', 'Roumanie',
#        'Royaume-Uni de Grande-Bretagne et d'Irlande du Nord', 'Rwanda',
#        'République de Corée', 'République de Moldova',
#        'République dominicaine', 'République populaire démocratique de Corée',
#        'Serbie', 'Sri Lanka', 'Suisse', 'Suède', 'Sénégal', 'Tchad',
#        'Thaïlande', 'Togo', 'Tunisie', 'Turquie', 'Ukraine', 'Uruguay',
#        'Venezuela (République bolivarienne du)', 'Viet Nam', 'Yémen', 'Zambie',
#        'Égypte', 'Équateur', 'États-Unis d'Amérique'],
#       dtype='object', name='Zone')

# %%
# Liste des pays dans clsuter 2

data_pca[data_pca.cluster_km == 2].index
# Out:
# Index(['Afghanistan', 'Belgique', 'Burkina Faso', 'Cabo Verde', 'Cambodge',
#        'Chine - RAS de Hong-Kong', 'Gambie', 'Guinée', 'Guinée-Bissau',
#        'Haïti', 'Kiribati', 'Madagascar', 'Malawi', 'Mali', 'Mauritanie',
#        'Mongolie', 'Mozambique', 'Népal', 'Pays-Bas',
#        'République centrafricaine', 'République-Unie de Tanzanie',
#        'Sao Tomé-et-Principe', 'Tadjikistan', 'Timor-Leste', 'Turkménistan',
#        'Vanuatu', 'Zimbabwe', 'Éthiopie'],
#       dtype='object', name='Zone')

# %%
# Liste des pays dans clsuter 3

data_pca[data_pca.cluster_km == 3].index
# Out:
# Index(['Angola', 'Arabie saoudite', 'Arménie', 'Autriche', 'Bulgarie', 'Bénin',
#        'Congo', 'Cuba', 'Danemark', 'Gabon', 'Ghana', 'Géorgie', 'Iraq',
#        'Irlande', 'Kazakhstan', 'Kirghizistan', 'Koweït', 'Libéria', 'Namibie',
#        'Oman', 'Sierra Leone', 'Slovaquie', 'Tchéquie', 'Émirats arabes unis'],
#       dtype='object', name='Zone')

# %% [markdown]
# <h2><span style="color:indianred"> 7. Analyse des clusters </span></h2>

# %% [markdown]
# ### Données à étudier

# %%
# Ajout de cluster sur les données

data_cluster = data_copy.merge(data_pca[['cluster_cah','cluster_km']], on = "Zone")
data_cluster.head()
# Out:
#              Zone  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0     Afghanistan                                             5.0
# 1  Afrique du Sud                                           143.0
# 2         Albanie                                            85.0
# 3         Algérie                                            22.0
# 4       Allemagne                                            71.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                               1.53
# 1                                              35.69
# 2                                              16.36
# 3                                               6.38
# 4                                              19.47
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                               0.33
# 1                                               9.25
# 2                                               6.45
# 3                                               1.50
# 4                                               4.16
#
#    Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                               0.54
# 1                                              14.11
# 2                                               6.26
# 3                                               1.97
# 4                                               7.96
#
#    Disponibilité intérieure  Exportations - Quantité  Importations - Quantité  \
# 0                      57.0               132.185185                     29.0
# 1                    2118.0                63.000000                    514.0
# 2                      47.0                 0.000000                     38.0
# 3                     277.0                 0.000000                      2.0
# 4                    1739.0               646.000000                    842.0
#
#    Production  Population  cluster_cah  cluster_km
# 0        28.0   27100.536            2           2
# 1      1667.0   49119.759            0           1
# 2        13.0    3033.998            1           0
# 3       275.0   34166.972            0           1
# 4      1514.0   81277.830            0           1

# %% [markdown]
# ### Analyse de clusters

# %%
# Distribution disponibilité alimentaire

fig = plt.figure(figsize = (20,8))

ax = fig.add_subplot(111)
sns.boxplot(data=data_cluster, x='Disponibilité alimentaire (Kcal/personne/jour)', y='cluster_km', orient = 'h',
            palette = 'RdYlGn')
plt.title("\nDisponibilité de volaille par cluster\n", fontsize = 18)

plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)

ax.set_ylabel('clusters K-means', size = 15)
ax.set_xlabel('Kcal/personne/jour', size = 15)
plt.tick_params(labelsize=15);

# %%
# Distribution disponibilité intérieure

fig = plt.figure(figsize = (20,8))

ax = fig.add_subplot(111)
sns.boxplot(data=data_cluster, x='Disponibilité intérieure', y='cluster_km', orient = 'h', 
            palette = 'RdYlGn', showfliers=False)
plt.title("\nDisponibilité intérieure de volaille par cluster\n", fontsize = 18)

plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)

ax.set_ylabel('clusters K-means', size = 15)
ax.set_xlabel('milliers de tonnes', size = 15)
plt.tick_params(labelsize=15);

# %%
# Distribution population

fig = plt.figure(figsize = (20,8))

ax = fig.add_subplot(111)
sns.boxplot(data=data_cluster, x='Population', y='cluster_km', orient = 'h', 
            palette = 'RdYlGn', showfliers=False)
plt.title("\nPopulation\n", fontsize = 18)

plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)

ax.set_ylabel('clusters K-means', size = 15)
ax.set_xlabel('1000 personnes', size = 15)
plt.tick_params(labelsize=15);

# %%
# Distribution production

fig = plt.figure(figsize = (20,8))

ax = fig.add_subplot(111)
sns.boxplot(data=data_cluster, x='Production', y='cluster_km', orient = 'h', 
            palette = 'RdYlGn',showfliers=False)
plt.title("\nProduction de volaille\n", fontsize = 18)

plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)

ax.set_ylabel('clusters K-means', size = 15)
ax.set_xlabel('milliers de tonnes', size = 15)
plt.tick_params(labelsize=15);

# %%
# Distribution Importation

fig = plt.figure(figsize = (20,8))

ax = fig.add_subplot(111)
sns.boxplot(data=data_cluster, x='Importations - Quantité', y='cluster_km', orient = 'h', 
            palette = 'RdYlGn',showfliers=False)
plt.title("\nImportation de volailles\n", fontsize = 18)

plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)

ax.set_ylabel('clusters K-means', size = 15)
ax.set_xlabel('milliers de tonnes', size = 15)
plt.tick_params(labelsize=15);

# %%
# Distribution Exportation

fig = plt.figure(figsize = (20,8))

ax = fig.add_subplot(111)
sns.boxplot(data=data_cluster, x='Exportations - Quantité', y='cluster_km', orient = 'h', 
            palette = 'RdYlGn',showfliers=False)
plt.title("\nExportation de volailles\n", fontsize = 18)

plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)

ax.set_ylabel('clusters K-means', size = 15)
ax.set_xlabel('milliers de tonnes', size = 15)
plt.tick_params(labelsize=15);

# %%
# Distribution Disponibilité protéine

fig = plt.figure(figsize = (20,8))

ax = fig.add_subplot(111)
sns.boxplot(data=data_cluster, x='Disponibilité de protéines en quantité (g/personne/jour)', y='cluster_km', 
            orient = 'h', palette = 'RdYlGn',showfliers=False)
plt.title("\nDisponibilité proteine\n", fontsize = 18)

plt.grid('whitegrid', color ='gray', alpha = 0.3)
plt.box(False)
plt.tick_params(bottom=False, left=False)

ax.set_ylabel('clusters K-means', size = 15)
ax.set_xlabel('g/personne/jour', size = 15)
plt.tick_params(labelsize=15);
